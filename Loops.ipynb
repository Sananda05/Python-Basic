# %% [markdown]
# <a href="https://colab.research.google.com/github/Sananda05/Python-Basic/blob/master/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tutorial 07

# %%
nums=[1,2,3,4,5]

for n in nums:
     if n== 3:
        print('Found')
        break
     print(n)

#NEsted Loop

for n in nums :
  for letter in 'abc':
    print(n,letter)

for i in range(10):
  print (i)    

x=0

while x < 10:
  
   print(x)
   x +=1   

#infinite loop
while True :
  print (x)
# Out:
# Streaming output truncated to the last 5000 lines.
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# ...
